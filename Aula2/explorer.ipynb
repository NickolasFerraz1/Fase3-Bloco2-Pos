# %% [markdown]
# # Explorer - Aula 2
#
# -- Antes -> Notebook de teste com células **executadas** (com output), para o `nbstripout --verify` detectar.
#
# -- Agora -> Notebook de teste sem célular **executadas**, fixed by nbstripout

# %%
print("Olá, MLOps!")

# %%
sum(range(11))
