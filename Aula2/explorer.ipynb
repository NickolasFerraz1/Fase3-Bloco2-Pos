# %% [markdown]
# # Explorer - Aula 2
#
# Notebook de teste com células **executadas** (com output), para o `nbstripout --verify` detectar.

# %%
print("Olá, MLOps!")
# Out:
# Olá, MLOps!

# %%
sum(range(11))
# Out:
# 55
